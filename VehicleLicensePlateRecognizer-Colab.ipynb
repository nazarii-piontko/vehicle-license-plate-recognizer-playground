# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !ln -s "/content/gdrive/My Drive/Projects/VehicleLicensePlateRecognizer/" /project

# %%
# %cd /project
# !ls -lah
# !ls -lah data/yolo

# %%
# !/usr/local/cuda/bin/nvcc --version
# !tar -xzvf /project/cudnn-10.1-linux-x64-v7.6.5.32.solitairetheme8 -C /usr/local/

# %%
# !rm -rf darknet
# !git clone https://github.com/pjreddie/darknet

# !sed -i '/GPU=0/c\GPU=1' darknet/Makefile
# !sed -i '/CUDNN=0/c\CUDNN=1' darknet/Makefile
# !sed -i '/OPENCV=0/c\OPENCV=1' darknet/Makefile
# !sed -i '/DEBUG=1/c\DEBUG=0' darknet/Makefile

# !cd darknet && make clean && make && cp darknet /usr/local/bin/

# !rm -rf darknet

# %%
# !rm -rf data/origin/openalpr
# !git clone https://github.com/openalpr/benchmarks data/origin/openalpr

# %%
# !python3 prepare-darknet-data.py
# !cat data/yolo/yolo.cfg

# %%
# !rm -rf data/origin/openalpr

# %%
# !darknet detector train data/yolo/yolo.data data/yolo/yolo.cfg data/yolo/darknet53.conv.74
# !darknet detector train data/yolo/yolo.data data/yolo/yolo.cfg data/yolo/backup/yolo.backup -clear
# !darknet detector test data/yolo/yolo.data data/yolo/yolo.cfg data/yolo/backup/yolo.backup data/yolo/data/test_076.jpg -out data/yolo/results/result
